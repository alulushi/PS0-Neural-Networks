# %%
import imageio
import matplotlib.pyplot as plt
    
pic = imageio.imread('./test_2.jpg')
plt.figure(figsize = (15, 15))
plt.imshow(pic)

# %%
print('Type of the image: ', type(pic), '\n')
print('Shape of the image: {}'.format(pic.shape))
print('Image height {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image:  <class 'imageio.core.util.Array'>
#
# Shape of the image: (450, 768, 3)
# Image height 450
# Image Width 768
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size))
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 1036800
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
pic[100, 50]
# Out:
# Array([ 95, 121,  47], dtype=uint8)

# %%
print('Value of only R channel {}'.format(pic[100, 50, 0]))
print('Value of only G channel {}'.format(pic[100, 50, 1]))
print('Value of only B channel {}'.format(pic[100, 50, 2]))
# Out:
# Value of only R channel 95
# Value of only G channel 121
# Value of only B channel 47

# %%
plt.title('R channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[:, :, 0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[:, :, 1])
plt.show()

# %%
plt.title('B channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))
plt.imshow(pic[:, :, 2])
plt.show()

# %%
pic = imageio.imread('./test_2.jpg')
pic[50:150, :, 0] = 255
plt.figure(figsize = (10, 10))
plt.imshow(pic)
plt.show()

# %%
pic[200:300, :, 1] = 255
plt.figure(figsize = (10, 10))
plt.imshow(pic)
plt.show()

# %%
pic[350:450, :, 2] = 255
plt.figure(figsize = (10, 10))
plt.imshow(pic)
plt.show()

# %%
pic[50:450, 400:600, [0,1,2]] = 200
plt.figure(figsize = (10, 10))
plt.imshow(pic)
plt.show()

# %%
import numpy as np

pic = imageio.imread("test_2.jpg")
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (15, 5))

for c, ax in zip(range(3), ax):
    split_img =  np.zeros(pic.shape, dtype = "uint8")
    split_img[:, :, c] = pic[:, :, c]
    
    ax.imshow(split_img)

# %%
pic = imageio.imread('test_2.jpg')
gray = lambda rgb:np.dot(rgb[...,:3], [0.299, 0.587, 0.114])
gray = gray(pic)
plt.figure(figsize = (10, 10))
plt.imshow(gray, cmap = plt.get_cmap(name = 'gray'))
plt.show()

# %%
pic = imageio.imread('test_2.jpg')
gray = lambda rgb:np.dot(rgb[...,:3], [0.21, 0.72, 0.07])
gray = gray(pic)
plt.figure(figsize = (10, 10))
plt.imshow(gray, cmap = plt.get_cmap(name = 'gray'))
plt.show()

print('Type of image: ', type(gray))
print()
print('Shape of image: {}'.format(gray.shape))
print('Image height {}'.format(gray.shape[0]))
print('Image width: {}'.format(gray.shape[1]))
print('Dimension of image {}'.format(gray.ndim))
print()
print('Image size: {}'.format(gray.size))
print('Max RGB value: {}'.format(gray.max()))
print('Min RGB value: {}'.format(gray.min()))
print('Random indexes: {}'.format(gray[100, 50]))
# Out:
# Type of image:  <class 'imageio.core.util.Array'>
#
# Shape of image: (450, 768)
# Image height 450
# Image width: 768
# Dimension of image 2
#
# Image size: 345600
# Max RGB value: 254.99999999999997
# Min RGB value: 0.0
# Random indexes: 110.36
